# %%
# This is used to increase the notebook's width to fill the screen, allowing for better plot visualization
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import os
import cv2
import time
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

from utils import plot
from utils import split
# Out:
# C:\Users\leoar\AppData\Local\Temp\ipykernel_18088\659568940.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # The  Dataset
#
#
#
# ## [Source]()

# %% [markdown]
# # Path to Dataset

# %%
# Relative path to dataset
data_dir = os.path.join( "..", "..", "..", "..", "Datasets", "COVID19", "Tomografia", "COVIDx CT-3A" )
assert os.path.exists( data_dir ), "Unable to find the relative path to COVIDx CT-3A, please check data_dir..."

#
dataset_name = "COVID-19-CT-Seg"

# %% [markdown]
# ## Samples Dataframe

# %%
# Path to metadata csv
csv_path = os.path.join( data_dir, "combined_metadata.csv" )

# Reads metadata as dataframe, "age" column is treated as str since "N/A" can't be int
samples_df = pd.read_csv(csv_path, sep = ";", na_filter = False, dtype={"age": str})

samples_df.head()
# Out:
#                filename patient_id source     class country sex   age  \
# 0  NCP_96_1328_0032.png     NCP_96   CNCB  COVID-19   China   M  74.0
# 1  NCP_96_1328_0035.png     NCP_96   CNCB  COVID-19   China   M  74.0
# 2  NCP_96_1328_0036.png     NCP_96   CNCB  COVID-19   China   M  74.0
# 3  NCP_96_1328_0037.png     NCP_96   CNCB  COVID-19   China   M  74.0
# 4  NCP_96_1328_0038.png     NCP_96   CNCB  COVID-19   China   M  74.0
#
#   partition slice_selection  x_min  y_min  x_max  y_max verified_finding  \
# 0     train          Expert      9     94    512    405              Yes
# 1     train          Expert     10    106    512    405              Yes
# 2     train          Expert     10    105    512    406              Yes
# 3     train          Expert     11    104    512    406              Yes
# 4     train          Expert     11    103    512    406              Yes
#
#     view modality
# 0  Axial       CT
# 1  Axial       CT
# 2  Axial       CT
# 3  Axial       CT
# 4  Axial       CT

# %% [markdown]
# ## Patients Dataframe

# %%
# Creates a new dataframe with metadata sorted by patient
patient_df = plot.convert_df_sample2patient( samples_df )

patient_df.head()
# Out:
#   patient_id source     class country  sex   age partition slice_selection  \
# 0     NCP_96   CNCB  COVID-19   China    M  74.0     train          Expert
# 1    NCP_270   CNCB  COVID-19   China  N/A   N/A     train          Expert
# 2    NCP_322   CNCB  COVID-19   China  N/A   N/A     train          Expert
# 3   NCP_1276   CNCB  COVID-19   China  N/A   N/A     train          Expert
# 4   NCP_2683   CNCB  COVID-19   China  N/A   N/A     train          Expert
#
#   verified_finding   view modality  sample_count
# 0              Yes  Axial       CT           121
# 1              Yes  Axial       CT           124
# 2              Yes  Axial       CT            40
# 3              Yes  Axial       CT            32
# 4              Yes  Axial       CT             9

# %%
figure = plt.figure( figsize = (36, 24) )
plot.column_per_partition_as_histogram( patient_df, "sample_count", dataset_name, figure, title_complement = "Patient")

# %%
counts_df = plot.column_bins_per_partition_as_df( patient_df, "sample_count", dataset_name )
counts_df.head(len(counts_df))
# Out:
#             Dataset  Train  Val  Test
# Values
# [0, 25)           1      0    0     1
# [25, 50)          4      1    1     2
# [50, 75)          2      0    1     1
# [75, 100)         1      0    1     0
# [100, 125)        4      4    0     0
# [125, 150)        3      3    0     0
# [150, 175)        1      1    0     0
# [175, 200)        2      0    1     1
# [200, 225)        0      0    0     0
# [225, 250)        0      0    0     0
# [250, 275)        0      0    0     0
# [275, 300)        0      0    0     0
# [300, 325)        0      0    0     0
# [325, 350)        0      0    0     0
# [350, 375)        0      0    0     0
# [375, 400)        0      0    0     0
# [400, 425)        0      0    0     0
# [425, 450)        0      0    0     0
# [450, 475)        0      0    0     0
# [475, 500)        0      0    0     0
# [500, 525)        0      0    0     0
# [525, 550)        0      0    0     0
# [550, 575)        0      0    0     0
# [575, 600)        0      0    0     0
# [600, 625)        0      0    0     0
# [625, 650)        0      0    0     0
# [650, 675)        0      0    0     0
# [675, 700)        0      0    0     0
# [700, 725)        0      0    0     0
# [725, 750)        0      0    0     0
# [750, 775)        0      0    0     0
# [775, 800)        0      0    0     0
# [800, 825)        0      0    0     0
# SUM              18      9    4     5

# %% [markdown]
# # Plots

# %% [markdown]
# ## Class

# %%
plot.column_as_pies( samples_df, patient_df, "class", dataset_name, figsize = (48, 24) )

# %%
plot.column_as_table( samples_df, patient_df, "class", dataset_name, bin_flag = False )
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>Sample Distribution
#  by Class</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>COVID-19</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#     <tr>
#       <th>Normal</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Pneumonia</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2>Patient Distribution
#  by Class</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>COVID-19</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Pneumonia</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Normal</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# ## Age

# %%
plot.column_as_pies( samples_df, patient_df, "age", dataset_name, figsize = (48, 24))

# %%
plot.column_as_table( samples_df, patient_df, "age", dataset_name, bin_flag = False )
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>Sample Distribution
#  by Age</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>N/A</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Known Ages</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2>Patient Distribution
#  by Age</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>N/A</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Known Ages</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
plot.column_as_histograms( samples_df, patient_df, "age", dataset_name, figsize = (36, 24))

# %%
plot.column_as_table( samples_df, patient_df, "age", dataset_name, bin_flag = True )
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>Sample Distribution
#  by Age</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>[0, 5)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[5, 10)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[10, 15)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[15, 20)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[20, 25)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[25, 30)</th>
#       <td>161</td>
#       <td>161</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[30, 35)</th>
#       <td>253</td>
#       <td>0</td>
#       <td>189</td>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>[35, 40)</th>
#       <td>72</td>
#       <td>0</td>
#       <td>72</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[40, 45)</th>
#       <td>215</td>
#       <td>101</td>
#       <td>114</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[45, 50)</th>
#       <td>239</td>
#       <td>239</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[50, 55)</th>
#       <td>169</td>
#       <td>134</td>
#       <td>0</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>[55, 60)</th>
#       <td>190</td>
#       <td>0</td>
#       <td>0</td>
#       <td>190</td>
#     </tr>
#     <tr>
#       <th>[60, 65)</th>
#       <td>245</td>
#       <td>245</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[65, 70)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[70, 75)</th>
#       <td>141</td>
#       <td>101</td>
#       <td>0</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>[75, 80)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[80, 85)</th>
#       <td>41</td>
#       <td>41</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[85, 90)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[90, 95)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[95, 100)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2>Patient Distribution
#  by Age</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>[0, 5)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[5, 10)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[10, 15)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[15, 20)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[20, 25)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[25, 30)</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[30, 35)</th>
#       <td>2</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>[35, 40)</th>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[40, 45)</th>
#       <td>3</td>
#       <td>1</td>
#       <td>2</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[45, 50)</th>
#       <td>2</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[50, 55)</th>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>[55, 60)</th>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>[60, 65)</th>
#       <td>2</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[65, 70)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[70, 75)</th>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>[75, 80)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[80, 85)</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[85, 90)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[90, 95)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>[95, 100)</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# ## Sex

# %%
plot.column_as_pies( samples_df, patient_df, "sex", dataset_name, figsize = (48, 24) )

# %%
plot.column_as_table( samples_df, patient_df, "sex", dataset_name, bin_flag = False )
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>Sample Distribution
#  by Sex</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>M</th>
#       <td>1028</td>
#       <td>676</td>
#       <td>222</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>N/A</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>F</th>
#       <td>698</td>
#       <td>346</td>
#       <td>153</td>
#       <td>199</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2>Patient Distribution
#  by Sex</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>N/A</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>M</th>
#       <td>11</td>
#       <td>6</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>F</th>
#       <td>7</td>
#       <td>3</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# ## Country

# %%
plot.column_as_pies( samples_df, patient_df, "country", dataset_name, figsize = (48, 24) )

# %%
plot.column_as_table( samples_df, patient_df, "country", dataset_name, bin_flag = False )
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>Sample Distribution
#  by Country</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>France</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>China</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Iran</th>
#       <td>196</td>
#       <td>161</td>
#       <td>0</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>USA</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>N/A</th>
#       <td>1243</td>
#       <td>719</td>
#       <td>270</td>
#       <td>254</td>
#     </tr>
#     <tr>
#       <th>Australia</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Italy</th>
#       <td>141</td>
#       <td>101</td>
#       <td>0</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>Algeria</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Belgium</th>
#       <td>72</td>
#       <td>0</td>
#       <td>72</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>England</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Scotland</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Turkey</th>
#       <td>41</td>
#       <td>41</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Azerbaijan</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Lebanon</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Ukraine</th>
#       <td>33</td>
#       <td>0</td>
#       <td>33</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Afghanistan</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Peru</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2>Patient Distribution
#  by Country</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>China</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>France</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Iran</th>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>N/A</th>
#       <td>10</td>
#       <td>6</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>USA</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Australia</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Algeria</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Italy</th>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Afghanistan</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Azerbaijan</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Belgium</th>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>England</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Lebanon</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Peru</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Scotland</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Turkey</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Ukraine</th>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# ## Partition

# %%
plot.column_as_pies( samples_df, patient_df, "partition", dataset_name, figsize = (48, 24) )

# %%
plot.column_as_table( samples_df, patient_df, "partition", dataset_name, bin_flag = False )
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>Sample Distribution
#  by Partition</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>1022</td>
#       <td>1022</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>329</td>
#       <td>0</td>
#       <td>0</td>
#       <td>329</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>375</td>
#       <td>0</td>
#       <td>375</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2>Patient Distribution
#  by Partition</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>9</td>
#       <td>9</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>4</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# ## Slice Selection

# %%
plot.column_as_pies( samples_df, patient_df, "slice_selection", dataset_name, figsize = (48, 24) )

# %%
plot.column_as_table( samples_df, patient_df, "slice_selection", dataset_name, bin_flag = False )
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>Sample Distribution
#  by Slice Selection</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Automatic</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Expert</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#     <tr>
#       <th>N/A</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Non-expert</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>1726</td>
#       <td>1022</td>
#       <td>375</td>
#       <td>329</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2>Patient Distribution
#  by Slice Selection</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dataset</th>
#       <th>Train</th>
#       <th>Val</th>
#       <th>Test</th>
#     </tr>
#     <tr>
#       <th>Values</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Automatic</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Expert</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>N/A</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Non-expert</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>SUM</th>
#       <td>18</td>
#       <td>9</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# # Data Split

# %%
# No Split was needed

# %% [markdown]
# # Registering Changes

# %%
# Path to save new metadata csv
csv_export_path = os.path.join( data_dir, "new_split_metadata.csv" )

updated_df = split.update_metadata_csv( csv_export_path, samples_df, dataset_name, save_bool = True )
print( len(updated_df), len(samples_df[ samples_df["source"] == dataset_name ]) )
updated_df.head()
# Out:
# 190923 1726
#                filename patient_id source     class country sex   age  \
# 0  NCP_96_1328_0032.png     NCP_96   CNCB  COVID-19   China   M  74.0
# 1  NCP_96_1328_0035.png     NCP_96   CNCB  COVID-19   China   M  74.0
# 2  NCP_96_1328_0036.png     NCP_96   CNCB  COVID-19   China   M  74.0
# 3  NCP_96_1328_0037.png     NCP_96   CNCB  COVID-19   China   M  74.0
# 4  NCP_96_1328_0038.png     NCP_96   CNCB  COVID-19   China   M  74.0
#
#   partition slice_selection  x_min  y_min  x_max  y_max verified_finding  \
# 0     train          Expert      9     94    512    405              Yes
# 1     train          Expert     10    106    512    405              Yes
# 2     train          Expert     10    105    512    406              Yes
# 3     train          Expert     11    104    512    406              Yes
# 4     train          Expert     11    103    512    406              Yes
#
#     view modality
# 0  Axial       CT
# 1  Axial       CT
# 2  Axial       CT
# 3  Axial       CT
# 4  Axial       CT
